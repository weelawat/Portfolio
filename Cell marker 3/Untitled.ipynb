# %%
from PIL import Image
import numpy as np
import cv2

pf = "Image27.tiff"

im = Image.open(pf)
imarray = np.array(im)

rimarray, gimarray, bimarray = cv2.split(imarray)

print(rimarray.shape)
print(rimarray.sum())
print(rimarray.mean())
Image.fromarray(imarray)
# Out:
# (1536, 2040)
# 5715166
# 1.8239270578022875
# <PIL.Image.Image image mode=RGB size=2040x1536 at 0x7FEB68E6A790>

# %%
Image.fromarray(rimarray)
# Out:
# <PIL.Image.Image image mode=L size=2040x1536 at 0x7FEB68E6A990>
